# %% [markdown]
# # GOAL-TO CREATE A MODEL TO PREDICT WHETHER OR NOT CUSTOMER WILL CHURN OR NOT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"A:\ML AI\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.countplot(data=df,x='Churn');
#Its not extremely imbalanced to be dealt with right now

# %%
sns.violinplot(data=df,y='TotalCharges',x='Churn');

# %%
sns.boxplot(data=df,y='TotalCharges',x='Churn');

# %%
plt.figure(figsize=(14,8),dpi=200)
sns.boxplot(data=df,y='TotalCharges',x='Contract',hue='Churn');
plt.legend(loc=(1.1,0.5));

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
corr_df  = pd.get_dummies(df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn']]).corr()

# %%
corr_yes_churn = corr_df['Churn_Yes'].sort_values().iloc[1:-1]

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=corr_yes_churn.index,y=corr_yes_churn.values);
plt.xticks(rotation=90);

# %% [markdown]
# # CHURN ANALYSIS

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
sns.histplot(x='tenure',bins=60,data=df);

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.displot(data=df,x='tenure',bins=70,row='Churn',col='Contract');

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=df,x='MonthlyCharges',y='TotalCharges',lw=0.5,alpha=0.5,palette='Dark2',hue='Churn')

# if you're getting charge a lot per month, you're very likely to churn, especially if you're on a month to month contract and you're only needing the service for
#few months.So maybe just get fed up with the service.You're paying too much.You're on a month to month, so you just quit and churn.
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# # Creating Cohorts based on Tenure
#
# **Let's begin by treating each unique tenure length, 1 month, 2 month, 3 month...N months as its own cohort.**
#
# **TASK: Treating each unique tenure group as a cohort, calculate the Churn rate (percentage that had Yes Churn) per cohort. For example, the cohort that has had a tenure of 1 month should have a Churn rate of 61.99%. You should have cohorts 1-72 months with a general trend of the longer the tenure of the cohort, the less of a churn rate. This makes sense as you are less likely to stop service the longer you've had it.**

# %%
no_churn = df.groupby(['Churn','tenure']).count().transpose()['No']
yes_churn = df.groupby(['Churn','tenure']).count().transpose()['Yes']

# %%
#no_churn
#yes_churn

# %%
churn_rate =100 * yes_churn / (no_churn+yes_churn)
churn_rate
# Out:
# tenure                   1          2     3          4          5          6   \
# customerID        61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# gender            61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# SeniorCitizen     61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# Partner           61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# Dependents        61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# PhoneService      61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# MultipleLines     61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# InternetService   61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# OnlineSecurity    61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# OnlineBackup      61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# DeviceProtection  61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# ...

# %%
churn_rate.transpose()['customerID'].plot()
# Out:
# <AxesSubplot:xlabel='tenure'>

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4),dpi=200)
churn_rate.iloc[0].plot()
plt.ylabel('Churn Percentage');

# %% [markdown]
# # Broader Cohort Groups
# ** Based on the tenure column values, create a new column called Tenure Cohort that creates 4 separate categories:**
#    * '0-12 Months'
#    * '24-48 Months'
#    * '12-24 Months'
#    * 'Over 48 Months'

# %%
def cohort(tenure):
    if tenure < 13:
        return '0-12 Months'
    elif tenure < 25:
        return '12-24 Months'
    elif tenure < 49:
        return '24-48 Months'
    else:
        return "Over 48 Months"

# %%
df['Tenure Cohort'] = df['tenure'].apply(cohort)
#New column Tenure Cohort

# %%
df.head(10)[['tenure','Tenure Cohort']]
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=df,x='MonthlyCharges',y='TotalCharges',lw=0.5,alpha=0.5,palette='Dark2',hue='Tenure Cohort');

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.countplot(data=df,x='Tenure Cohort',hue='Churn');

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.catplot(data=df,x='Tenure Cohort',hue='Churn',col='Contract',kind='count');

# %% [markdown]
# # -----
#
# # Part 4: Predictive Modeling
#
# **Let's explore 4 different tree based methods: A Single Decision Tree, Random Forest, AdaBoost, Gradient Boosting.
#
#
# ## Single Decision Tree

# %%
X = df.drop(['Churn','customerID'],axis=1)
y = df['Churn']

# %%
X = pd.get_dummies(X,drop_first=True)
X
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0                 0       1           29.85         29.85            0
# 1                 0      34           56.95       1889.50            1
# 2                 0       2           53.85        108.15            1
# 3                 0      45           42.30       1840.75            1
# 4                 0       2           70.70        151.65            0
# ...             ...     ...             ...           ...          ...
# 7027              0      24           84.80       1990.50            1
# 7028              0      72          103.20       7362.90            0
# 7029              0      11           29.60        346.45            0
# 7030              1       4           74.40        306.60            1
# 7031              0      66          105.65       6844.50            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0               1               0                 0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=6)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
pred = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report,plot_confusion_matrix,accuracy_score

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.81       704

# %%
plot_confusion_matrix(dt,X_test,y_test)
# Out:
# C:\Users\ADIYAKANTA\Downloads\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
dt.feature_importances_
# Out:
# array([0.0126805 , 0.42391407, 0.04492202, 0.06350564, 0.00123697,
#        0.        , 0.        , 0.00785158, 0.        , 0.01243191,
#        0.31406016, 0.        , 0.        , 0.00837585, 0.        ,
#        0.00534132, 0.02628952, 0.        , 0.        , 0.00786752,
#        0.        , 0.        , 0.        , 0.        , 0.01002118,
#        0.02706543, 0.        , 0.        , 0.03443632, 0.        ,
#        0.        , 0.        , 0.        ])

# %%
imp_feats = pd.DataFrame(data=dt.feature_importances_,index=X.columns,columns=['Feature Importance'])

# %%
imp_feats = imp_feats.sort_values('Feature Importance')

# %%
plt.figure(figsize=(14,6),dpi=200)
sns.barplot(data=imp_feats.sort_values('Feature Importance'),x=imp_feats.sort_values('Feature Importance').index,y='Feature Importance')
plt.xticks(rotation=90)
plt.title("Feature Importance for Decision Tree");

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(12,8),dpi=150)
plot_tree(dt,filled=True,feature_names=X.columns);

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100)

# %%
rf.fit(X_train,y_train)
preds = rf.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.80       704

# %%
plot_confusion_matrix(dt,X_test,y_test)
# Out:
# C:\Users\ADIYAKANTA\Downloads\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # BOOSTED TREES

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier

# %%
ada_model = AdaBoostClassifier()
ada_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
ad_preds = ada_model.predict(X_test)
gb_preds = gb.predict(X_test)

# %%
print(classification_report(y_test,ad_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %%
print(classification_report(y_test,gb_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.90      0.89       557
#          Yes       0.57      0.50      0.53       147
#
#     accuracy                           0.82       704
#    macro avg       0.72      0.70      0.71       704
# weighted avg       0.81      0.82      0.81       704

# %%
plot_confusion_matrix(ada_model,X_test,y_test)
# Out:
# C:\Users\ADIYAKANTA\Downloads\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
plot_confusion_matrix(gb,X_test,y_test)
# Out:
# C:\Users\ADIYAKANTA\Downloads\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # With base models, we got best performance from an AdaBoostClassifier, but note, we didn't do any gridsearching AND most models performed about the same on the data set.
